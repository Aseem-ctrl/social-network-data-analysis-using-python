# %%
data = {
    "users": [
        {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
        {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
        {"id": 3, "name": "", "friends": [1], "liked_pages": [101, 103]},
        {"id": 4, "name": "Sara", "friends": [2, 2], "liked_pages": [104]},
        {"id": 5, "name": "Amit", "friends": [], "liked_pages": []}
    ],
    "pages": [
        {"id": 101, "name": "Python Developers"},
        {"id": 102, "name": "Data Science Enthusiasts"},
        {"id": 103, "name": "AI & ML Community"},
        {"id": 104, "name": "Web Dev Hub"},
        {"id": 104, "name": "Web Development"}
    ]
}

# ----------------------------
# Clean Users
# ----------------------------

name_count = {}
clean_users = []

for user in data["users"]:
    # Replace empty name
    if user["name"] == "":
        user["name"] = "Unknown"

    # Handle duplicate names
    name = user["name"]

    if name in name_count:
        name_count[name] += 1
        user["name"] = f"{name}{name_count[name]}"
    else:
        name_count[name] = 0

    # Remove duplicate friends
    user["friends"] = list(set(user["friends"]))

    clean_users.append(user)

# ----------------------------
# Clean Pages
# ----------------------------

seen_page_ids = set()
clean_pages = []

for page in data["pages"]:
    if page["id"] not in seen_page_ids:
        clean_pages.append(page)
        seen_page_ids.add(page["id"])

# ----------------------------
# Create Friends Table
# ----------------------------

friends_table = []

for user in clean_users:
    for friend_id in user["friends"]:
        friends_table.append({
            "user_id": user["id"],
            "friend_id": friend_id
        })

# ----------------------------
# Create Likes Table
# ----------------------------

likes_table = []

for user in clean_users:
    for page_id in user["liked_pages"]:
        likes_table.append({
            "user_id": user["id"],
            "page_id": page_id
        })

# ----------------------------
# Output
# ----------------------------

print("CLEAN USERS")
for user in clean_users:
    print(user)

print("\nCLEAN PAGES")
for page in clean_pages:
    print(page)

print("\nFRIENDS TABLE")
for row in friends_table:
    print(row)

print("\nLIKES TABLE")
for row in likes_table:
    print(row)
# Out:
# CLEAN USERS
# {'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}
# {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}
# {'id': 3, 'name': 'Unknown', 'friends': [1], 'liked_pages': [101, 103]}
# {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}
# {'id': 5, 'name': 'Amit1', 'friends': [], 'liked_pages': []}
#
# CLEAN PAGES
# {'id': 101, 'name': 'Python Developers'}
# {'id': 102, 'name': 'Data Science Enthusiasts'}
# {'id': 103, 'name': 'AI & ML Community'}
# {'id': 104, 'name': 'Web Dev Hub'}
#
# FRIENDS TABLE
# {'user_id': 1, 'friend_id': 2}
# {'user_id': 1, 'friend_id': 3}
# {'user_id': 2, 'friend_id': 1}
# {'user_id': 2, 'friend_id': 4}
# {'user_id': 3, 'friend_id': 1}
# {'user_id': 4, 'friend_id': 2}
#
# LIKES TABLE
# {'user_id': 1, 'page_id': 101}
# {'user_id': 2, 'page_id': 102}
# {'user_id': 3, 'page_id': 101}
# {'user_id': 3, 'page_id': 103}
# {'user_id': 4, 'page_id': 104}
